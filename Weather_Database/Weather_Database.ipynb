# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | bontang
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | muisne
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | bandiagara
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | boa vista
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | charlestown
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | allapalli
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | chapais
# Processing Record 28 of Set 1 | severo-yeniseyskiy
# Processing Record 29 of Set 1 | sao miguel do iguacu
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | kununurra
# Processing Record 33 of Set 1 | sao geraldo do araguaia
# Processing Record 34 of Set 1 | shimoda
# Processing Record 35 of Set 1 | ushtobe
# Processing Record 36 of Set 1 | vardo
# Processing Record 37 of Set 1 | tessalit
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | bubaque
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | brownsville
# Processing Record 44 of Set 1 | sandwick
# Processing Record 45 of Set 1 | vao
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | poum
# Processing Record 49 of Set 1 | tupik
# Processing Record 50 of Set 1 | portobelo
# Processing Record 1 of Set 2 | lewistown
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | calvinia
# Processing Record 4 of Set 2 | hambantota
# Processing Record 5 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 6 of Set 2 | la ronge
# Processing Record 7 of Set 2 | snasa
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | cherskiy
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | malindi
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | coihaique
# Processing Record 17 of Set 2 | oktyabrskoye
# Processing Record 18 of Set 2 | los llanos de aridane
# Processing Record 19 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | road town
# Processing Record 23 of Set 2 | rognan
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | aklavik
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | ust-tsilma
# Processing Record 29 of Set 2 | sarakhs
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | swellendam
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | biak
# Processing Record 34 of Set 2 | sitka
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | isla mujeres
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | preobrazheniye
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | kayerkan
# Processing Record 45 of Set 2 | cape coast
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | merauke
# Processing Record 49 of Set 2 | wukari
# Processing Record 50 of Set 2 | batesville
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | nome
# Processing Record 3 of Set 3 | northam
# Processing Record 4 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 3 | de aar
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | plastun
# Processing Record 9 of Set 3 | yulara
# Processing Record 10 of Set 3 | pierre
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | cockburn town
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | rio gallegos
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | derzhavinsk
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | monte alegre
# Processing Record 21 of Set 3 | komsomolskiy
# Processing Record 22 of Set 3 | skelleftea
# Processing Record 23 of Set 3 | mount isa
# Processing Record 24 of Set 3 | mount gambier
# Processing Record 25 of Set 3 | coahuayana
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | namibe
# Processing Record 28 of Set 3 | narok
# Processing Record 29 of Set 3 | husavik
# Processing Record 30 of Set 3 | aksarka
# Processing Record 31 of Set 3 | egvekinot
# Processing Record 32 of Set 3 | bonavista
# Processing Record 33 of Set 3 | bichena
# Processing Record 34 of Set 3 | mahibadhoo
# Processing Record 35 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | garden acres
# Processing Record 38 of Set 3 | tiarei
# Processing Record 39 of Set 3 | nemuro
# Processing Record 40 of Set 3 | yarada
# Processing Record 41 of Set 3 | bullhead city
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | badin
# Processing Record 45 of Set 3 | lorengau
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | rab
# City not found. Skipping...
# Processing Record 48 of Set 3 | jiwani
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | carauari
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | zaysan
# Processing Record 3 of Set 4 | cururupu
# Processing Record 4 of Set 4 | theunissen
# Processing Record 5 of Set 4 | vytegra
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | krasnoselkup
# Processing Record 8 of Set 4 | hovd
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | storsteinnes
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | melfi
# Processing Record 13 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 14 of Set 4 | usinsk
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | grindavik
# Processing Record 17 of Set 4 | vanavara
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | teya
# Processing Record 20 of Set 4 | nova odesa
# Processing Record 21 of Set 4 | beringovskiy
# Processing Record 22 of Set 4 | chuy
# Processing Record 23 of Set 4 | altay
# Processing Record 24 of Set 4 | udachnyy
# Processing Record 25 of Set 4 | burnie
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | longyearbyen
# Processing Record 28 of Set 4 | broome
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | kendari
# Processing Record 31 of Set 4 | donauworth
# Processing Record 32 of Set 4 | pabrade
# Processing Record 33 of Set 4 | denpasar
# Processing Record 34 of Set 4 | kahului
# Processing Record 35 of Set 4 | esperance
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | sobolevo
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | haileybury
# Processing Record 40 of Set 4 | odienne
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | koygorodok
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | krasnyye baki
# Processing Record 45 of Set 4 | acari
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | kodinsk
# Processing Record 48 of Set 4 | tazovskiy
# Processing Record 49 of Set 4 | port macquarie
# Processing Record 50 of Set 4 | jaciara
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | east london
# Processing Record 3 of Set 5 | coos bay
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | vilyuysk
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | miracatu
# Processing Record 8 of Set 5 | virginia beach
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | yaan
# Processing Record 11 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 12 of Set 5 | iqaluit
# Processing Record 13 of Set 5 | liverpool
# Processing Record 14 of Set 5 | ferkessedougou
# Processing Record 15 of Set 5 | karuzi
# Processing Record 16 of Set 5 | elizabeth city
# Processing Record 17 of Set 5 | grao mogol
# Processing Record 18 of Set 5 | oksfjord
# Processing Record 19 of Set 5 | sioux lookout
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 5 | omsukchan
# Processing Record 23 of Set 5 | lethem
# Processing Record 24 of Set 5 | tyrma
# Processing Record 25 of Set 5 | manglaur
# Processing Record 26 of Set 5 | balrampur
# Processing Record 27 of Set 5 | paraiso
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | cayenne
# Processing Record 31 of Set 5 | serov
# Processing Record 32 of Set 5 | rantepao
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | flinders
# Processing Record 35 of Set 5 | hithadhoo
# Processing Record 36 of Set 5 | herat
# Processing Record 37 of Set 5 | dennery
# Processing Record 38 of Set 5 | kamaishi
# Processing Record 39 of Set 5 | babaeski
# Processing Record 40 of Set 5 | rindal
# Processing Record 41 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 5 | christchurch
# Processing Record 43 of Set 5 | sumbe
# Processing Record 44 of Set 5 | atherton
# Processing Record 45 of Set 5 | linxia
# Processing Record 46 of Set 5 | sovetskoye
# Processing Record 47 of Set 5 | margate
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | ola
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | luanda
# Processing Record 4 of Set 6 | jiangyou
# Processing Record 5 of Set 6 | burica
# City not found. Skipping...
# Processing Record 6 of Set 6 | victor harbor
# Processing Record 7 of Set 6 | chany
# Processing Record 8 of Set 6 | bonthe
# Processing Record 9 of Set 6 | lagoa
# Processing Record 10 of Set 6 | kenai
# Processing Record 11 of Set 6 | nantucket
# Processing Record 12 of Set 6 | santa lucia
# Processing Record 13 of Set 6 | darhan
# Processing Record 14 of Set 6 | caravelas
# Processing Record 15 of Set 6 | sur
# Processing Record 16 of Set 6 | puerto escondido
# Processing Record 17 of Set 6 | haines junction
# Processing Record 18 of Set 6 | chokurdakh
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | santa isabel do rio negro
# Processing Record 21 of Set 6 | los andes
# Processing Record 22 of Set 6 | loanda
# Processing Record 23 of Set 6 | prince rupert
# Processing Record 24 of Set 6 | general roca
# Processing Record 25 of Set 6 | somotillo
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | dickinson
# Processing Record 29 of Set 6 | matara
# Processing Record 30 of Set 6 | carnarvon
# Processing Record 31 of Set 6 | hualmay
# Processing Record 32 of Set 6 | murgab
# Processing Record 33 of Set 6 | la rioja
# Processing Record 34 of Set 6 | kuminskiy
# Processing Record 35 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 6 | deputatskiy
# Processing Record 37 of Set 6 | la asuncion
# Processing Record 38 of Set 6 | balkhash
# Processing Record 39 of Set 6 | khorixas
# Processing Record 40 of Set 6 | rafaela
# Processing Record 41 of Set 6 | itarema
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | nenjiang
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | saint-marc-des-carrieres
# Processing Record 46 of Set 6 | tamiahua
# Processing Record 47 of Set 6 | saint-joseph
# Processing Record 48 of Set 6 | wajima
# Processing Record 49 of Set 6 | susanville
# Processing Record 50 of Set 6 | port hardy
# Processing Record 1 of Set 7 | gushikawa
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | hami
# Processing Record 4 of Set 7 | hobyo
# Processing Record 5 of Set 7 | kaeo
# Processing Record 6 of Set 7 | luklukan
# Processing Record 7 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 7 | arkhangelos
# City not found. Skipping...
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | kabanjahe
# Processing Record 11 of Set 7 | te anau
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | dicabisagan
# Processing Record 14 of Set 7 | tombouctou
# Processing Record 15 of Set 7 | neryungri
# Processing Record 16 of Set 7 | taonan
# Processing Record 17 of Set 7 | libreville
# Processing Record 18 of Set 7 | lloydminster
# Processing Record 19 of Set 7 | constitucion
# Processing Record 20 of Set 7 | isiro
# Processing Record 21 of Set 7 | the valley
# Processing Record 22 of Set 7 | bacolod
# Processing Record 23 of Set 7 | aswan
# Processing Record 24 of Set 7 | acarau
# Processing Record 25 of Set 7 | mahebourg
# Processing Record 26 of Set 7 | brae
# Processing Record 27 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | awjilah
# Processing Record 29 of Set 7 | mecca
# Processing Record 30 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 7 | niamey
# Processing Record 32 of Set 7 | tshikapa
# Processing Record 33 of Set 7 | tangier
# Processing Record 34 of Set 7 | pujili
# Processing Record 35 of Set 7 | tanout
# Processing Record 36 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 7 | lata
# Processing Record 38 of Set 7 | narsaq
# Processing Record 39 of Set 7 | goderich
# Processing Record 40 of Set 7 | shenjiamen
# Processing Record 41 of Set 7 | stornoway
# Processing Record 42 of Set 7 | ostrovnoy
# Processing Record 43 of Set 7 | lavrentiya
# Processing Record 44 of Set 7 | zalantun
# Processing Record 45 of Set 7 | el alto
# Processing Record 46 of Set 7 | along
# Processing Record 47 of Set 7 | sorong
# Processing Record 48 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 7 | namuac
# Processing Record 50 of Set 7 | avera
# Processing Record 1 of Set 8 | san julian
# Processing Record 2 of Set 8 | iquique
# Processing Record 3 of Set 8 | tiznit
# Processing Record 4 of Set 8 | honiara
# Processing Record 5 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 6 of Set 8 | caxito
# Processing Record 7 of Set 8 | touros
# Processing Record 8 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 9 of Set 8 | beloha
# Processing Record 10 of Set 8 | kaputa
# Processing Record 11 of Set 8 | pietarsaari
# Processing Record 12 of Set 8 | sabang
# Processing Record 13 of Set 8 | camacupa
# Processing Record 14 of Set 8 | okha
# Processing Record 15 of Set 8 | qiongshan
# Processing Record 16 of Set 8 | janakpur
# Processing Record 17 of Set 8 | san jeronimo
# Processing Record 18 of Set 8 | antofagasta
# Processing Record 19 of Set 8 | kusti
# Processing Record 20 of Set 8 | sao joao da barra
# Processing Record 21 of Set 8 | iskateley
# Processing Record 22 of Set 8 | cazanesti
# Processing Record 23 of Set 8 | amberley
# Processing Record 24 of Set 8 | leningradskiy
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | timmins
# Processing Record 27 of Set 8 | viedma
# Processing Record 28 of Set 8 | cilegon
# Processing Record 29 of Set 8 | havoysund
# Processing Record 30 of Set 8 | nacogdoches
# Processing Record 31 of Set 8 | hurricane
# Processing Record 32 of Set 8 | gasa
# Processing Record 33 of Set 8 | umm kaddadah
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 8 | mubi
# Processing Record 37 of Set 8 | banjar
# Processing Record 38 of Set 8 | tarauaca
# Processing Record 39 of Set 8 | izhma
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | atar
# Processing Record 42 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 8 | tabou
# Processing Record 44 of Set 8 | ancud
# Processing Record 45 of Set 8 | punta cardon
# Processing Record 46 of Set 8 | carballo
# Processing Record 47 of Set 8 | canutama
# Processing Record 48 of Set 8 | naze
# Processing Record 49 of Set 8 | euclides da cunha
# Processing Record 50 of Set 8 | dongsheng
# Processing Record 1 of Set 9 | korla
# Processing Record 2 of Set 9 | yar-sale
# Processing Record 3 of Set 9 | muktagachha
# City not found. Skipping...
# Processing Record 4 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 9 | ha giang
# Processing Record 6 of Set 9 | zhangye
# Processing Record 7 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 9 | manta
# Processing Record 9 of Set 9 | magistralnyy
# Processing Record 10 of Set 9 | williams lake
# Processing Record 11 of Set 9 | cabedelo
# Processing Record 12 of Set 9 | sao borja
# Processing Record 13 of Set 9 | codajas
# Processing Record 14 of Set 9 | asau
# Processing Record 15 of Set 9 | holme
# Processing Record 16 of Set 9 | peniche
# Processing Record 17 of Set 9 | ha tinh
# Processing Record 18 of Set 9 | mount vernon
# Processing Record 19 of Set 9 | kavaratti
# Processing Record 20 of Set 9 | alice springs
# Processing Record 21 of Set 9 | hamilton
# Processing Record 22 of Set 9 | ocos
# Processing Record 23 of Set 9 | almaznyy
# Processing Record 24 of Set 9 | cacoal
# Processing Record 25 of Set 9 | elat
# Processing Record 26 of Set 9 | halifax
# Processing Record 27 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 9 | san isidro
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | tuatapere
# Processing Record 31 of Set 9 | barcelos
# Processing Record 32 of Set 9 | yoichi
# Processing Record 33 of Set 9 | nanyuki
# Processing Record 34 of Set 9 | kyabe
# Processing Record 35 of Set 9 | ilulissat
# Processing Record 36 of Set 9 | xai-xai
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | dzhebariki-khaya
# Processing Record 39 of Set 9 | shingu
# Processing Record 40 of Set 9 | tautira
# Processing Record 41 of Set 9 | juneau
# Processing Record 42 of Set 9 | nizhniy baskunchak
# Processing Record 43 of Set 9 | sechura
# Processing Record 44 of Set 9 | high level
# Processing Record 45 of Set 9 | kloulklubed
# Processing Record 46 of Set 9 | saldanha
# Processing Record 47 of Set 9 | pevek
# Processing Record 48 of Set 9 | lubao
# Processing Record 49 of Set 9 | hirara
# Processing Record 50 of Set 9 | pinega
# Processing Record 1 of Set 10 | hun
# Processing Record 2 of Set 10 | ponta delgada
# Processing Record 3 of Set 10 | tawang
# Processing Record 4 of Set 10 | luwuk
# Processing Record 5 of Set 10 | puerto suarez
# Processing Record 6 of Set 10 | heinola
# Processing Record 7 of Set 10 | henties bay
# Processing Record 8 of Set 10 | bahir dar
# Processing Record 9 of Set 10 | paamiut
# Processing Record 10 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 10 | gap
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | marsa matruh
# Processing Record 14 of Set 10 | oktyabrskiy
# Processing Record 15 of Set 10 | ghugus
# Processing Record 16 of Set 10 | coquimbo
# Processing Record 17 of Set 10 | ormara
# Processing Record 18 of Set 10 | saint-augustin
# Processing Record 19 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 10 | north bend
# Processing Record 21 of Set 10 | rotenburg
# Processing Record 22 of Set 10 | syracuse
# Processing Record 23 of Set 10 | algiers
# Processing Record 24 of Set 10 | liku
# Processing Record 25 of Set 10 | kijang
# Processing Record 26 of Set 10 | male
# Processing Record 27 of Set 10 | brewster
# Processing Record 28 of Set 10 | oga
# Processing Record 29 of Set 10 | westport
# Processing Record 30 of Set 10 | barwani
# Processing Record 31 of Set 10 | hauterive
# Processing Record 32 of Set 10 | zuwarah
# Processing Record 33 of Set 10 | auki
# Processing Record 34 of Set 10 | orlik
# Processing Record 35 of Set 10 | pali
# Processing Record 36 of Set 10 | bezhanitsy
# Processing Record 37 of Set 10 | leninsk
# Processing Record 38 of Set 10 | ahipara
# Processing Record 39 of Set 10 | sola
# Processing Record 40 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 10 | bolu
# Processing Record 42 of Set 10 | anqing
# Processing Record 43 of Set 10 | tutoia
# Processing Record 44 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 10 | ozernovskiy
# Processing Record 46 of Set 10 | arroyo
# Processing Record 47 of Set 10 | vikhorevka
# Processing Record 48 of Set 10 | grootfontein
# Processing Record 49 of Set 10 | sao lourenco do sul
# Processing Record 50 of Set 10 | san quintin
# Processing Record 1 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 2 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 11 | hailar
# Processing Record 4 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 11 | mossendjo
# Processing Record 6 of Set 11 | pocao de pedras
# Processing Record 7 of Set 11 | ubon ratchathani
# Processing Record 8 of Set 11 | cleveland
# Processing Record 9 of Set 11 | cairns
# Processing Record 10 of Set 11 | palma
# Processing Record 11 of Set 11 | flin flon
# Processing Record 12 of Set 11 | lerwick
# Processing Record 13 of Set 11 | palauig
# Processing Record 14 of Set 11 | cervo
# Processing Record 15 of Set 11 | bairiki
# Processing Record 16 of Set 11 | bathurst
# Processing Record 17 of Set 11 | fort nelson
# Processing Record 18 of Set 11 | uroteppa
# City not found. Skipping...
# Processing Record 19 of Set 11 | san cristobal
# Processing Record 20 of Set 11 | saint-pierre
# Processing Record 21 of Set 11 | san rafael
# Processing Record 22 of Set 11 | bani
# Processing Record 23 of Set 11 | sukumo
# Processing Record 24 of Set 11 | ketchikan
# Processing Record 25 of Set 11 | lasa
# Processing Record 26 of Set 11 | raudeberg
# Processing Record 27 of Set 11 | seoul
# Processing Record 28 of Set 11 | porto franco
# Processing Record 29 of Set 11 | walvis bay
# Processing Record 30 of Set 11 | terrace bay
# Processing Record 31 of Set 11 | siyabuswa
# Processing Record 32 of Set 11 | amapa
# Processing Record 33 of Set 11 | pangody
# Processing Record 34 of Set 11 | beidao
# Processing Record 35 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 11 | yayva
# Processing Record 37 of Set 11 | tibati
# Processing Record 38 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 11 | pontes e lacerda
# Processing Record 40 of Set 11 | nara
# Processing Record 41 of Set 11 | wattegama
# Processing Record 42 of Set 11 | carmen
# Processing Record 43 of Set 11 | springdale
# Processing Record 44 of Set 11 | olinda
# Processing Record 45 of Set 11 | aransas pass
# Processing Record 46 of Set 11 | nelson bay
# Processing Record 47 of Set 11 | lingao
# Processing Record 48 of Set 11 | galesong
# Processing Record 49 of Set 11 | inirida
# Processing Record 50 of Set 11 | borogontsy
# Processing Record 1 of Set 12 | salinas
# Processing Record 2 of Set 12 | almazar
# Processing Record 3 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 4 of Set 12 | saint george
# Processing Record 5 of Set 12 | tigil
# Processing Record 6 of Set 12 | collecchio
# Processing Record 7 of Set 12 | tucupita
# Processing Record 8 of Set 12 | souillac
# Processing Record 9 of Set 12 | ichinohe
# Processing Record 10 of Set 12 | tornio
# Processing Record 11 of Set 12 | keningau
# Processing Record 12 of Set 12 | moerai
# Processing Record 13 of Set 12 | evensk
# Processing Record 14 of Set 12 | datong
# Processing Record 15 of Set 12 | huarmey
# Processing Record 16 of Set 12 | liptovsky mikulas
# Processing Record 17 of Set 12 | ust-kulom
# Processing Record 18 of Set 12 | yerbogachen
# Processing Record 19 of Set 12 | imeni poliny osipenko
# Processing Record 20 of Set 12 | oneonta
# Processing Record 21 of Set 12 | zhangjiakou
# Processing Record 22 of Set 12 | baoding
# Processing Record 23 of Set 12 | dangriga
# Processing Record 24 of Set 12 | mitsamiouli
# Processing Record 25 of Set 12 | fujin
# Processing Record 26 of Set 12 | cosala
# Processing Record 27 of Set 12 | japura
# Processing Record 28 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 12 | pella
# Processing Record 30 of Set 12 | minervino murge
# Processing Record 31 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 12 | subaytilah
# City not found. Skipping...
# Processing Record 33 of Set 12 | kongolo
# Processing Record 34 of Set 12 | bull savanna
# Processing Record 35 of Set 12 | plettenberg bay
# Processing Record 36 of Set 12 | ocampo
# Processing Record 37 of Set 12 | goundi
# Processing Record 38 of Set 12 | bandarbeyla
# Processing Record 39 of Set 12 | turhal
# Processing Record 40 of Set 12 | lamu
# Processing Record 41 of Set 12 | simao
# Processing Record 42 of Set 12 | saint anthony
# Processing Record 43 of Set 12 | asaba
# Processing Record 44 of Set 12 | morro bay
# Processing Record 45 of Set 12 | conakry
# Processing Record 46 of Set 12 | tacoronte
# Processing Record 47 of Set 12 | jalu
# Processing Record 48 of Set 12 | shizunai
# Processing Record 49 of Set 12 | krylovskaya
# Processing Record 50 of Set 12 | bud
# Processing Record 1 of Set 13 | richards bay
# Processing Record 2 of Set 13 | isangel
# Processing Record 3 of Set 13 | sambava
# Processing Record 4 of Set 13 | kirakira
# Processing Record 5 of Set 13 | miyako
# Processing Record 6 of Set 13 | yambio
# Processing Record 7 of Set 13 | mizan teferi
# Processing Record 8 of Set 13 | port hedland
# Processing Record 9 of Set 13 | benguela
# Processing Record 10 of Set 13 | plainview
# Processing Record 11 of Set 13 | sekoma
# Processing Record 12 of Set 13 | tezu
# Processing Record 13 of Set 13 | sotnikovo
# Processing Record 14 of Set 13 | wuhu
# Processing Record 15 of Set 13 | nerchinskiy zavod
# Processing Record 16 of Set 13 | pereleshinskiy
# Processing Record 17 of Set 13 | solnechnyy
# Processing Record 18 of Set 13 | tapiramuta
# Processing Record 19 of Set 13 | hervey bay
# Processing Record 20 of Set 13 | nishihara
# Processing Record 21 of Set 13 | ereymentau
# Processing Record 22 of Set 13 | binzhou
# Processing Record 23 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 13 | galle
# Processing Record 25 of Set 13 | tuyen quang
# Processing Record 26 of Set 13 | calama
# Processing Record 27 of Set 13 | santa cruz
# Processing Record 28 of Set 13 | necochea
# Processing Record 29 of Set 13 | oss
# Processing Record 30 of Set 13 | banda aceh
# Processing Record 31 of Set 13 | tsabong
# Processing Record 32 of Set 13 | adolfo lopez mateos
# Processing Record 33 of Set 13 | barabash
# Processing Record 34 of Set 13 | faya
# Processing Record 35 of Set 13 | gat
# Processing Record 36 of Set 13 | pangnirtung
# Processing Record 37 of Set 13 | gerash
# Processing Record 38 of Set 13 | praia
# Processing Record 39 of Set 13 | fairbanks
# Processing Record 40 of Set 13 | sumter
# Processing Record 41 of Set 13 | oulainen
# Processing Record 42 of Set 13 | praia da vitoria
# Processing Record 43 of Set 13 | santa cruz de tenerife
# Processing Record 44 of Set 13 | ossora
# Processing Record 45 of Set 13 | trento
# Processing Record 46 of Set 13 | kadugannawa
# Processing Record 47 of Set 13 | puerto varas
# Processing Record 48 of Set 13 | tunoshna
# Processing Record 49 of Set 13 | bria
# Processing Record 50 of Set 13 | laguna
# Processing Record 1 of Set 14 | north shore
# Processing Record 2 of Set 14 | libohove
# Processing Record 3 of Set 14 | nkhata bay
# Processing Record 4 of Set 14 | padang
# Processing Record 5 of Set 14 | rocky mountain house
# Processing Record 6 of Set 14 | amahai
# Processing Record 7 of Set 14 | ust-koksa
# Processing Record 8 of Set 14 | kaoma
# Processing Record 9 of Set 14 | blairmore
# Processing Record 10 of Set 14 | grajau
# Processing Record 11 of Set 14 | quang ngai
# Processing Record 12 of Set 14 | kristiansund
# Processing Record 13 of Set 14 | wilmington
# Processing Record 14 of Set 14 | suntar
# Processing Record 15 of Set 14 | kerrville
# Processing Record 16 of Set 14 | tabuk
# Processing Record 17 of Set 14 | arequipa
# Processing Record 18 of Set 14 | visnes
# Processing Record 19 of Set 14 | hindaun
# Processing Record 20 of Set 14 | sao joao do piaui
# Processing Record 21 of Set 14 | blagoveshchensk
# Processing Record 22 of Set 14 | berdigestyakh
# Processing Record 23 of Set 14 | akdepe
# Processing Record 24 of Set 14 | waipawa
# Processing Record 25 of Set 14 | anadyr
# Processing Record 26 of Set 14 | rabaul
# Processing Record 27 of Set 14 | cap malheureux
# Processing Record 28 of Set 14 | shitanjing
# Processing Record 29 of Set 14 | broken hill
# Processing Record 30 of Set 14 | mehamn
# Processing Record 31 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 14 | sembe
# Processing Record 33 of Set 14 | maputo
# Processing Record 34 of Set 14 | tabasco
# Processing Record 35 of Set 14 | kallaste
# Processing Record 36 of Set 14 | shadegan
# Processing Record 37 of Set 14 | morros
# Processing Record 38 of Set 14 | pandamatenga
# Processing Record 39 of Set 14 | nouadhibou
# Processing Record 40 of Set 14 | san andres
# Processing Record 41 of Set 14 | meadow lake
# Processing Record 42 of Set 14 | vestmannaeyjar
# Processing Record 43 of Set 14 | hackettstown
# Processing Record 44 of Set 14 | puri
# Processing Record 45 of Set 14 | kudahuvadhoo
# Processing Record 46 of Set 14 | dalbandin
# Processing Record 47 of Set 14 | pocos de caldas
# Processing Record 48 of Set 14 | artigas
# Processing Record 49 of Set 14 | chisinau
# Processing Record 50 of Set 14 | beyneu
# Processing Record 1 of Set 15 | grenfell
# Processing Record 2 of Set 15 | moron
# Processing Record 3 of Set 15 | valdivia
# Processing Record 4 of Set 15 | nyrob
# Processing Record 5 of Set 15 | conde
# Processing Record 6 of Set 15 | sinnamary
# Processing Record 7 of Set 15 | itacare
# Processing Record 8 of Set 15 | baijiantan
# Processing Record 9 of Set 15 | macusani
# Processing Record 10 of Set 15 | muros
# Processing Record 11 of Set 15 | filadelfia
# Processing Record 12 of Set 15 | manicore
# Processing Record 13 of Set 15 | bilma
# Processing Record 14 of Set 15 | dangara
# Processing Record 15 of Set 15 | frontera
# Processing Record 16 of Set 15 | oranjestad
# Processing Record 17 of Set 15 | bambanglipuro
# Processing Record 18 of Set 15 | ibra
# Processing Record 19 of Set 15 | ajdabiya
# Processing Record 20 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 15 | rodrigues alves
# Processing Record 22 of Set 15 | kuandian
# Processing Record 23 of Set 15 | doha
# Processing Record 24 of Set 15 | cooma
# Processing Record 25 of Set 15 | mastic beach
# Processing Record 26 of Set 15 | sabha
# Processing Record 27 of Set 15 | sosnovo-ozerskoye
# Processing Record 28 of Set 15 | vanimo
# Processing Record 29 of Set 15 | kysyl-syr
# Processing Record 30 of Set 15 | katima mulilo
# Processing Record 31 of Set 15 | pemba
# Processing Record 32 of Set 15 | lakes entrance
# Processing Record 33 of Set 15 | kidal
# Processing Record 34 of Set 15 | rio grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avarua      CK -21.2078 -159.7750     78.85        83          95
# 1   Punta Arenas      CL -53.1500  -70.9167     51.91        71          75
# 2        Bontang      ID   0.1333  117.5000     83.30        69          98
# 3    New Norfolk      AU -42.7826  147.0587     78.66        36          73
# 4         Muisne      EC   0.6000  -80.0333     75.49        86          97
# 5          Vaini      TO -21.2000 -175.2000     78.96       100         100
# 6      Saskylakh      RU  71.9167  114.0833     -7.78        88          98
# 7        Mataura      NZ -46.1927  168.8643     59.49        43           0
# 8     Bandiagara      ML  14.3501   -3.6104     66.99        13           0
# 9  Mar Del Plata      AR -38.0023  -57.5575     63.88        77           0
#
#    Wind Speed   Current Description
# 0       10.36       overcast clouds
# 1       27.63         broken clouds
# 2       10.25  heavy intensity rain
# 3        3.00         broken clouds
# 4        0.96            light rain
# 5        5.75       overcast clouds
# 6       10.29       overcast clouds
# 7        2.46             clear sky
# 8        9.19             clear sky
# 9        1.01             clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
